# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahtesham-Ibne-Mostafa/Natural_Language_Processing/blob/main/NLP_Youtube_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import metrics

import string
import spacy

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/youtoxic_english_1000.csv')

# %%
data
# Out:
#                 CommentId      VideoId  ... IsReligiousHate  IsRadicalism
# 0    Ugg2KwwX0V8-aXgCoAEC  04kJtp6pVXI  ...           False         False
# 1    Ugg2s5AzSPioEXgCoAEC  04kJtp6pVXI  ...           False         False
# 2    Ugg3dWTOxryFfHgCoAEC  04kJtp6pVXI  ...           False         False
# 3    Ugg7Gd006w1MPngCoAEC  04kJtp6pVXI  ...           False         False
# 4    Ugg8FfTbbNF8IngCoAEC  04kJtp6pVXI  ...           False         False
# ..                    ...          ...  ...             ...           ...
# 995  Ugi5ADt10EdDz3gCoAEC  XRuCW80L9mA  ...           False         False
# 996  Ugifh2DMhBbDkHgCoAEC  XRuCW80L9mA  ...           False         False
# 997  Ugj_plbGBjjzYXgCoAEC  XRuCW80L9mA  ...           False         False
# 998  Ugj0bah1De8xy3gCoAEC  XRuCW80L9mA  ...           False         False
# 999  UgjBJKQSoQMQ6ngCoAEC  XRuCW80L9mA  ...           False         False
#
# [1000 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CommentId        1000 non-null   object
#  1   VideoId          1000 non-null   object
#  2   Text             1000 non-null   object
#  3   IsToxic          1000 non-null   bool
#  4   IsAbusive        1000 non-null   bool
#  5   IsThreat         1000 non-null   bool
#  6   IsProvocative    1000 non-null   bool
#  7   IsObscene        1000 non-null   bool
#  8   IsHatespeech     1000 non-null   bool
#  9   IsRacist         1000 non-null   bool
#  10  IsNationalist    1000 non-null   bool
#  11  IsSexist         1000 non-null   bool
#  12  IsHomophobic     1000 non-null   bool
#  13  IsReligiousHate  1000 non-null   bool
#  14  IsRadicalism     1000 non-null   bool
# dtypes: bool(12), object(3)
# memory usage: 35.3+ KB

# %%
nlp = spacy.load("en_core_web_sm")
stop_words = nlp.Defaults.stop_words
print(stop_words)
# Out:
# {'back', 'anyhow', 'any', 'not', 'itself', 'over', 'could', 'get', 'full', 'themselves', 'them', 'although', 'something', 'because', 'its', 'both', 'though', 'further', 'latter', 'within', "n't", 'anything', 'neither', 'who', 'such', 'if', 'the', 'cannot', 'thru', 'via', 'has', 'he', 'anyway', 'toward', 'nor', 'anywhere', '’ll', 'we', 'a', 'where', "'re", 'everywhere', 'here', 'for', 'which', 'did', 'will', 'either', 'whom', 'after', 're', 'until', 'wherein', 'have', 'their', 'towards', 'say', 'therein', 'so', 'few', 'third', 'rather', 'thus', 'when', 'amount', 'one', '’m', 'whereby', 'almost', 'she', 'should', 'was', 'hundred', 'this', 'yourself', 'become', 'seem', 'an', 'there', 'during', 'afterwards', 'last', 'others', 'many', 'against', 'now', 'but', 'had', 'everyone', 'does', 'also', 'it', 'very', 'herein', 'behind', 'four', 'fifteen', 'together', 'name', 'done', 'be', 'thereupon', 'whereupon', 'whose', 'i', 'what', 'me', 'show', 'on', '‘ve', 'his', '‘ll', 'around', "'ll", 'mine
# ...

# %%
punctuations = string.punctuation
print(punctuations)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# Creating our tokenizer function
def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    doc = nlp(sentence)



    print(doc)
    print(type(doc))

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [ word.lemma_.lower().strip() for word in doc ]

    print(mytokens)

    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return preprocessed list of tokens
    return mytokens

# %%
sentence = "I am eating apple ?"
spacy_tokenizer(sentence)
# Out:
# I am eating apple ?
# <class 'spacy.tokens.doc.Doc'>
# ['i', 'be', 'eat', 'apple', '?']
# ['eat', 'apple']
